# %%
# !pip install plotly requests
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (9.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (26.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.1.4)

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
# Fetch global COVID data
url_global = "https://disease.sh/v3/covid-19/all"
global_data = requests.get(url_global).json()

# Fetch country-wise data
url_countries = "https://disease.sh/v3/covid-19/countries"
countries_data = requests.get(url_countries).json()

# Convert to DataFrame
df = pd.DataFrame(countries_data)

# Display first 5 rows
df.head()
# Out:
#          updated      country  \
# 0  1770894653649  Afghanistan
# 1  1770894653643      Albania
# 2  1770894653646      Algeria
# 3  1770894653692      Andorra
# 4  1770894653672       Angola
#
#                                          countryInfo   cases  todayCases  \
# 0  {'_id': 4, 'iso2': 'AF', 'iso3': 'AFG', 'lat':...  234174           0
# 1  {'_id': 8, 'iso2': 'AL', 'iso3': 'ALB', 'lat':...  334863           0
# 2  {'_id': 12, 'iso2': 'DZ', 'iso3': 'DZA', 'lat'...  272010           0
# 3  {'_id': 20, 'iso2': 'AD', 'iso3': 'AND', 'lat'...   48015           0
# 4  {'_id': 24, 'iso2': 'AO', 'iso3': 'AGO', 'lat'...  107327           0
#
#    deaths  todayDeaths  recovered  todayRecovered  active  ...    tests  \
# 0    7996            0     211080               0   15098  ...  1390730
# 1    3605            0     330233               0    1025  ...  1941032
# 2    6881            0     183061               0   82068  ...   230960
# 3     165            0          0               0   47850  ...   249838
# 4    1937            0     103419               0    1971  ...  1499795
#
#    testsPerOneMillion  population  continent  oneCasePerPeople  \
# 0               34125    40754388       Asia               174
# 1              677173     2866374     Europe                 9
# 2                5093    45350148     Africa               167
# 3             3225256       77463     Europe                 2
# 4               42818    35027343     Africa               326
#
#    oneDeathPerPeople oneTestPerPeople  activePerOneMillion  \
# 0               5097               29               370.46
# 1                795                1               357.59
# 2               6591              196              1809.65
# 3                469                0            617714.26
# 4              18083               23                56.27
#
#    recoveredPerOneMillion  criticalPerOneMillion
# 0                 5179.32                    0.0
# 1               115209.32                    0.0
# 2                 4036.61                    0.0
# 3                    0.00                    0.0
# 4                 2952.52                    0.0
#
# [5 rows x 23 columns]

# %%
# Select important columns
df = df[['country', 'cases', 'todayCases', 'deaths',
         'todayDeaths', 'recovered', 'active',
         'critical', 'tests', 'population']]

# Sort by total cases
df = df.sort_values(by='cases', ascending=False)

df.head()
# Out:
#      country      cases  todayCases   deaths  todayDeaths  recovered  \
# 218      USA  111820082           0  1219487            0  109814428
# 94     India   45035393           0   533570            0          0
# 71    France   40138560           0   167642            0   39970918
# 77   Germany   38828995           0   183027            0   38240600
# 26    Brazil   38743918           0   711380            0   36249161
#
#        active  critical       tests  population
# 218    786167       940  1186851502   334805269
# 94   44501823         0   935879495  1406631776
# 71          0         0   271490188    65584518
# 77     405368         0   122332384    83883596
# 26    1783377         0    63776166   215353593

# %%
top10 = df.head(10)
plt.figure(figsize=(8, 6))
sns.barplot(x='country', y='cases', data=top10)
fig = px.bar(top10,
             x='country',
             y='cases',
             title='Top 10 Countries by Total COVID Cases',
             color='cases',
             text='cases')

plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='country', y='deaths', data=top10)
plt.show() # Display the seaborn plot

fig_cases_deaths = px.scatter(df,
                 x='cases',
                 y='deaths',
                 size='recovered',
                 color='country',
                 hover_name='country',
                 title='Cases vs Deaths (Bubble Size = Recovered)')
fig_cases_deaths.show() # Display the plotly scatter plot
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7879c895-01f7-4ad9-a78b-257975906b43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7879c895-01f7-4ad9-a78b-257975906b43")) {                    Plotly.newPlot(                        "7879c895-01f7-4ad9-a78b-257975906b43",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=USA\u003cbr\u003ecases=%{x}\u003cbr\u003edeaths=%{y}\u003cbr\u003erecovered=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["USA"],"legendgroup":"USA","marker":{"color":"#636efa","size":[109814428],"sizemode":"area","sizeref":274536.07,"symbol":"circle"},"mode":"markers","name":"USA","orientation":"v","showlegend":true,"x":[111820082],"xaxis":"x","y":[1219487],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=India\u003cbr\u003ecases=%{x}\u003cbr\u003edeaths=%{y}\u003cbr\u003erecovered=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["India"],"legendgroup":"India","marker":{"color":"#EF553B","size":[0],"sizemode":"area","sizeref":274536.07,"symbol":"circle"},"mode":"markers","name":"India","orientation":"v","showlegend":true,"x":[45035393],"xaxis":"x","y":[533570],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=France\u003cbr\u003ecases=%{x}\u003cbr\u003edeaths=%{y}\u003cbr\u003erecovered=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["France"],"legendgroup":"France","marker":{"color":"#00cc96","size":[39970918],"sizemode":"area","sizeref":274536.07,"symbol":"circle"},"mode":"markers","name":"France","orientation":"v","showlegend":true,"x":[40138560],"xaxis":"x","y":[167642],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=Germany\u003cbr\u003ecases=%{x}\u003cbr\u003edeaths=%{y}\u003cbr\u003erecovered=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Germany"],"legendgroup":"Germany","marker":{"color":"#ab63fa","size":[38240600],"sizemode":"area","sizeref":274536.07,"symbol":"circle"},"mode":"markers","name":"Germany","orientation":"v","showlegend":true,"x":[38828995],"xaxis":"x","y":[183027],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=Brazil\u003cbr\u003ecases=%{x}\u003cbr\u003edeaths=%{y}\u003cbr\u003erecovered=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Brazil"],"legendgroup":"Brazil","marker":{"color":"#FFA15A","size":[36249161],"sizemode":"area","sizeref":274536.07,"symbol":"circle"},"mode":"markers","name":"Brazil","orientation":"v","showlegend":true,"x":[38743918],"xaxis":"x","y":[711380],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=S. Korea\u003cbr\u003ecases=%{x}\u003cbr\u003edeaths=%{y}\u003cbr\u003erecovered=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["S. Korea"],"legendgroup":"S. Korea","marker":{"color":"#19d3f3","size":[34535939],"sizemode":"area","sizeref":274536.07,"symbol":"circle"},"mode":"markers","name":"S. Korea","orientation":"v","showlegend":true,"x":[34571873],"xaxis":"x","y":[35934],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=Japan\u003cbr\u003ecases=%{x}\u003cbr\u003edeaths=%{y}\u003cbr\u003erecovered=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Japan"],"legendgroup":"Japan","marker":{"color":"#FF6692","size":[0],"siz ...

# %%
fig_active_critical = px.bar(df.head(10),
             x='country',
             y=['active', 'critical'],
             barmode='group',
             title='Active vs Critical Cases (Top 10 Countries)')

fig_active_critical.show()

# Removed seaborn barplot to avoid plt conflict and redundant plotting
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ef8b4d60-84b8-4317-a4aa-68612f675299" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef8b4d60-84b8-4317-a4aa-68612f675299")) {                    Plotly.newPlot(                        "ef8b4d60-84b8-4317-a4aa-68612f675299",                        [{"alignmentgroup":"True","hovertemplate":"variable=active\u003cbr\u003ecountry=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"active","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"active","offsetgroup":"active","orientation":"v","showlegend":true,"textposition":"auto","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"xaxis":"x","y":[786167,44501823,0,405368,1783377,0,33728878,165544,0,175641],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=critical\u003cbr\u003ecountry=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"critical","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"critical","offsetgroup":"critical","orientation":"v","showlegend":true,"textposition":"auto","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"xaxis":"x","y":[940,0,0,0,0,0,0,22,0,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f92 ...

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='country', y='tests', data=top10)
plt.show() # Display the seaborn plot

fig_map = px.choropleth(df,
                    locations="country",
                    locationmode="country names",
                    color="cases",
                    hover_name="country",
                    color_continuous_scale="Reds",
                    title="Worldwide COVID-19 Cases Map")
fig_map.show() # Display the plotly map
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6330c27a-dd40-487e-a258-8f04969bae21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6330c27a-dd40-487e-a258-8f04969bae21")) {                    Plotly.newPlot(                        "6330c27a-dd40-487e-a258-8f04969bae21",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=%{location}\u003cbr\u003ecases=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia","Turkey","Spain","Australia","Vietnam","Taiwan","Argentina","Netherlands","Mexico","Iran","Indonesia","Poland","Colombia","Greece","Austria","Portugal","Ukraine","Chile","Malaysia","Canada","Belgium","Israel","N. Korea","Thailand","Czechia","Peru","Switzerland","Philippines","South Africa","Romania","Denmark","Singapore","Hong Kong","Sweden","New Zealand","Serbia","Iraq","Hungary","Bangladesh","Slovakia","Georgia","Jordan","Ireland","Pakistan","Finland","Norway","Kazakhstan","Lithuania","Slovenia","Bulgaria","Croatia","Guatemala","Morocco","Lebanon","Costa Rica","Bolivia","Tunisia","Cuba","Ecuador","UAE","Panama","Uruguay","Mongolia","Nepal","Belarus","Latvia","Saudi Arabia","Paraguay","Azerbaijan","Bahrain","Cyprus","Dominican Republic","Sri Lanka","Kuwait","Myanmar","Moldova","Estonia","Palestine","Venezuela","Egypt","Qatar","Libyan Arab Jamahiriya","China","Ethiopia","Réunion","Honduras","Armenia","Bosnia","Oman","Luxembourg","Macedonia","Zambia","Kenya","Brunei","Albania","Botswana","Montenegro","Algeria","Nigeria","Zimbabwe","Uzbekistan","Afghanistan","Mozambique","Martinique","Lao People's Democratic Republic","Iceland","Kyrgyzstan","Guadeloupe","El Salvador","Trinidad and Tobago","Maldives","Namibia","Uganda","Ghana","Jamaica","Cambodia","Rwanda","Cameroon","Malta","Barbados","Angola","Channel Islands","DRC","French Guiana","Malawi","Senegal","Côte d'Ivoire","Suriname","New Caledonia","French Polynesia","Swaziland","Guyana","Belize","Fiji","Madagascar","Cabo Verde","Sudan","Mauritania","Bhutan","Syrian Arab Republic","Burundi","Seychelles","Gabon","Andorra","Papua New Guinea","Curaçao","Aruba","Tanzania","Mauritius","Mayotte","Togo","Guinea","Bahamas","Isle of Man","Lesotho","Haiti","Faroe Islands","Mali","Cayman Islands","Saint Lucia","Benin","Macao","Somalia","Micronesia","San Marino","Solomon Islands","Congo","Timor-Leste","Burkina Faso","Liechtenstein","Gibraltar","Grenada","Bermuda","South Sudan","Nicaragua","Tajikistan","Equatorial Guinea","Monaco","Samoa","Tonga","Marshall Islands","Dominica","Djibouti","Central African Republic","Gambia","Saint Martin","Vanuatu","Greenland","Yemen","Caribbean Netherlands","Sint Maarten","Eritrea","Niger","Saint Vincent and the Grenadines","Guinea-Bissau","Comoros","Antigua and Barbuda","Liberia","Sierra Leone","Chad","British Virgin Islands","Cook Islands","Sao Tome and Principe","Turks and Caicos Islands","Saint Kitts and Nevis","Palau","St. Barth","Nauru","Kiribati","Anguilla","Wallis and Futuna","Saint Pierre Miquelon","Tuvalu","Saint Helena","Falkland Islands (Malvinas)","Montserrat","Niue","Diamond Princess","Tokelau","Holy See (Vatican City State)","Western Sahara","MS Zaandam"],"locationmode":"country names","locations":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia","Turkey","Spain","Australia","Vietnam","Taiwan","Argentina","Netherlands","Mexico","Iran","Indonesia","Poland","Colombia","Greece","Austria","Portugal","Ukraine","Chile","Malaysia","Canada","Belgium","Israel","N. Korea","Thailand","Czechia","Peru","Switzerland","Philippines","South Africa","Romania","Denmark","Singapore ...

# %%
url_vaccine = "https://disease.sh/v3/covid-19/vaccine/coverage/countries?lastdays=1"
vaccine_data = requests.get(url_vaccine).json()

# Convert to DataFrame
vaccine_list = []

for country in vaccine_data:
    vaccine_list.append({
        "country": country['country'],
        "vaccinations": list(country['timeline'].values())[0]
    })

vaccine_df = pd.DataFrame(vaccine_list)

vaccine_df.head()
# Out:
#        country  vaccinations
# 0  Afghanistan      22964750
# 1      Albania       3088966
# 2      Algeria      15267442
# 3      Andorra        157072
# 4       Angola      27819132

# %%
top_vaccine = vaccine_df.sort_values(by="vaccinations", ascending=False).head(10)
plt.figure(figsize=(8, 6))
sns.barplot(x="country", y="vaccinations", data=top_vaccine)
plt = px.bar(top_vaccine,
             x="country",
             y="vaccinations",
             title="Top 10 Countries by Vaccinations",
             color="vaccinations")

plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="efe2ad78-3834-4e84-af01-f23a8b49b820" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efe2ad78-3834-4e84-af01-f23a8b49b820")) {                    Plotly.newPlot(                        "efe2ad78-3834-4e84-af01-f23a8b49b820",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003evaccinations=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[3491077000,2206868000,676728782,486436436,448199860,383747738,361742554,340974144,266492149,223158993],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["China","India","USA","Brazil","Indonesia","Japan","Bangladesh","Pakistan","Vietnam","Mexico"],"xaxis":"x","y":[3491077000,2206868000,676728782,486436436,448199860,383747738,361742554,340974144,266492149,223158993],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"tick ...

# %%
country_name = input("Enter Country Name: ")

country_data = df[df['country'].str.lower() == country_name.lower()]

if not country_data.empty:
    print(country_data)
else:
    print("Country not found!")
# Out:
# Enter Country Name: India
#    country     cases  todayCases  deaths  todayDeaths  recovered    active  \
# 94   India  45035393           0  533570            0          0  44501823
#
#     critical      tests  population
# 94         0  935879495  1406631776

# %%
print("🌍 Global COVID-19 Summary")
print("Total Cases:", global_data['cases'])
print("Total Deaths:", global_data['deaths'])
print("Total Recovered:", global_data['recovered'])
print("Total Active:", global_data['active'])
# Out:
# 🌍 Global COVID-19 Summary
# Total Cases: 704753890
# Total Deaths: 7010681
# Total Recovered: 675619811
# Total Active: 22123398
